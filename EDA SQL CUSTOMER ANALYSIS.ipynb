# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:407351@localhost:3306/customer_behaviour
# Out:
# Connecting and switching to connection 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'

# %%
# %%sql
# SELECT *
# FROM
#     customer;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 5000 rows affected.
# +-------------+-----+--------+----------------+-------------+-----------------+----------------+-----------+--------+--------+---------------+---------------------+----------------+------------------+--------------------+----------------+------------------------+
# | customer_id | age | gender | item_purchased |   category  | purchase_amount |    location    |    size   | color  | season | review_rating | subscription_status | shipping_type  | discount_applied | previous_purchases | payment_method | frequency_of_purchases |
# +-------------+-----+--------+----------------+-------------+-----------------+----------------+-----------+--------+--------+---------------+---------------------+----------------+------------------+--------------------+----------------+------------------------+
# |     2701    |  22 | Female |    T-shirt     |   Clothing  |       68.0      |   California   |     XL    | Olive  | Winter |      3.2      |          No         |    Standard    |        No        |        36.0        |      Cash      |         Weekly         |
# |     521     |  51 |  Male  |   Sunglasses   | Accessories |       84.0      | South Carolina | Free Size | White  | Spring |      3.9      |         Yes         | Free Shipping  |       Yes        |        20.0        |   Debit Card   |       Quarterly        |
# |     3157    |  18 | Female |     Shirt      |   Clothing  |       50.0      |    Montana     |     M     | Black  | Winter |      3.1      |          No         | 2-Day Shipping |        No        |        18.0        |      Cash      |        Monthly         |
# |     1687    |  22 |  Male  |     Gloves     | Accessories |       75.0      |    Illinois    | Free Size |  Red   |  Fall  |      4.2      |          No         |  Store Pickup  |        No        |        25.0        |      Cash      |        Annually        |
# |     2929    |  40 | Female |    Jewelry     | Accessories |       80.0      |    Alabama     | Free Size | Yellow | Spring |      3.6      |          No         |  Store Pickup  |        No        |        17.0        |  Credit Card   |         Weekly         |
# |     3583    |  23 | Female |     Shorts     |   Clothing  |       41.0      |   California   |     S     | Beige  | Summer |      3.4      |          No         | 2-Day Shipping |        No        |        15.0        |     PayPal     |        Annually        |
# |     1135    |  62 |  Male  |    T-shirt     |   Clothing  |       81.0      |   Wisconsin    |     M     | Brown  | Summer |      3.85     |          No         |    Express     |       Yes        |        2.0         |     Venmo      |     Every 3 Months     |
# |     1411    |  61 |  Male  |      Hat       | Accessories |       93.0      |   Tennessee    | Free Size | Purple | Summer |      4.0      |          No         |  Store Pickup  |       Yes        |        18.0        |   Debit Card   |        Annually        |
# |     113     |  37 |  Male  |     Gloves     | Accessories |       65.0      |    Florida     | Free Size |  Red   | Spring |      4.3      |         Yes         | Free Shipping  |       Yes        |        28.0        |     PayPal     |       Bi-Weekly        |
# |     166     |  42 |  Male  |    Handbag     | Accessories |       60.0      |    Kentucky    | Free Size | Yellow | Winter |      2.8      |         Yes         |  Store Pickup  |       Yes        |        7.0         |      Cash      |        Monthly         |
# +-------------+-----+--------+----------------+-------------+-----------------+----------------+-----------+--------+--------+---------------+---------------------+----------------+------------------+--------------------+----------------+------------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ## Answering key bussiness questions

# %%
# %%sql
# -- Which category generates the highest revenue
#
# SELECT
#     category,
#     round(sum(purchase_amount),2) as Total_revenue
# FROM
#     customer
# GROUP BY
#     category
# ORDER BY
#     Total_revenue DESC
# LIMIT 10;
#
#
# -- Business Problem - Company does not know which category contributes most to revenue
# -- Impact :
# 			 -- Helps prioritize high-performing categories
# 			 -- Optimizes inventory planning
# 			 -- Improves marketing ROI
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 5 rows affected.
# +-------------+---------------+
# |   category  | Total_revenue |
# +-------------+---------------+
# | Electronics |   485769.23   |
# | Accessories |   197477.29   |
# |   Clothing  |   170062.58   |
# |   Footwear  |    93980.29   |
# |  Outerwear  |    18524.0    |
# +-------------+---------------+

# %%
# %%sql
# -- Are discounts actually increasing purchase value?
# SELECT
#     discount_applied,
#     round(sum(purchase_amount),2) as Total_revenue,
#     round(AVG(purchase_amount),2) as Avg_revenue
# FROM
#     customer
# GROUP BY
#     discount_applied;
#
# -- Business Problem - Discounts may reduce profit without increasing sales.
#
# -- Impact :
# 				--Identify effectiveness of discounts
# 				--Reduce unnecessary discount costs
# 				--Improve profit margins
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 2 rows affected.
# +------------------+---------------+-------------+
# | discount_applied | Total_revenue | Avg_revenue |
# +------------------+---------------+-------------+
# |        No        |    490990.5   |    178.15   |
# |       Yes        |   474822.89   |    211.6    |
# +------------------+---------------+-------------+

# %%
# %%sql
# -- What is the total revenue generated by male and female customer ?
# SELECT
#     gender,
#     round(sum(purchase_amount),2) as Total_revenue
# FROM
#     customer
# GROUP BY
#     gender
# ORDER BY
#     Total_revenue DESC;
#
# -- Business Problem - Lack of understanding of revenue contribution by gender segments.
#
# -- Impact:
# 			--Helps design targeted marketing campaigns
# 			--Improves customer segmentation strategy
# 			--Enhances personalization efforts
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 3 rows affected.
# +--------+---------------+
# | gender | Total_revenue |
# +--------+---------------+
# |  Male  |    382019.1   |
# | Female |   341054.44   |
# | Other  |   242739.85   |
# +--------+---------------+

# %%
# %%sql
# -- Which customer used a discount but still spent more than the average purchase amount?
# SELECT
#     customer_id,
#     purchase_amount,
#     discount_applied
#
# FROM
#     customer
# WHERE
#     purchase_amount > (
#     SELECT
#         round(AVG(purchase_amount),2) as Avg_revenue
#     FROM
#         customer)
# AND
#     discount_applied = 'Yes'
# ORDER BY purchase_amount DESC;
#
# -- Business Problem - Company cannot identify high-spending customers who are also discount users.
#
#
# -- Impact -
# 			--Identifies premium discount-sensitive customers
# 			--Enables targeted discount campaigns
# 			--Improves customer retention and revenue
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 441 rows affected.
# +-------------+-----------------+------------------+
# | customer_id | purchase_amount | discount_applied |
# +-------------+-----------------+------------------+
# |     4977    |     1499.76     |       Yes        |
# |     4055    |     1493.56     |       Yes        |
# |     4226    |     1472.22     |       Yes        |
# |     4600    |     1460.51     |       Yes        |
# |     4662    |     1459.59     |       Yes        |
# |     4408    |     1456.31     |       Yes        |
# |     5091    |     1451.07     |       Yes        |
# |     4573    |     1441.51     |       Yes        |
# |     4940    |     1439.75     |       Yes        |
# |     4079    |     1438.53     |       Yes        |
# +-------------+-----------------+------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Which are the top 5 products with the highest average review rating.
# SELECT
#     item_purchased,
#     round(AVG(review_rating),2) as Avg_rating
# FROM
#     customer
# GROUP BY
#     item_purchased
# ORDER BY
#     Avg_rating DESC
# LIMIT 5;
#
# -- Business Problem - No visibility into product performance based on customer satisfaction.
#
# -- Impact -
# 				--Promotes high-performing products
# 				--Improves low-rated products
# 				--Enhances customer experience
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 5 rows affected.
# +----------------+------------+
# | item_purchased | Avg_rating |
# +----------------+------------+
# |     Gloves     |    3.86    |
# |    Sandals     |    3.85    |
# |     Boots      |    3.82    |
# |      Hat       |    3.8     |
# |     Skirt      |    3.79    |
# +----------------+------------+

# %%
# %%sql
# -- Which are the bottom 5 products with the highest average review rating.
# SELECT
#     item_purchased,
#     round(AVG(review_rating),2) as Avg_rating
# FROM
#     customer
# GROUP BY
#     item_purchased
# ORDER BY
#     Avg_rating ASC
# LIMIT 5;
#
# -- Business Problem - No visibility into product performance based on customer satisfaction.
#
# -- Impact -
# 				--Promotes high-performing products
# 				--Improves low-rated products
# 				--Enhances customer experience
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 5 rows affected.
# +----------------+------------+
# | item_purchased | Avg_rating |
# +----------------+------------+
# |     Phone      |    2.97    |
# |   Headphones   |    3.04    |
# |     Watch      |    3.05    |
# |     Laptop     |    3.09    |
# |      Bag       |    3.09    |
# +----------------+------------+

# %%
# %%sql
# SELECT *
# FROM
#     customer
# LIMIT 3;
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 3 rows affected.
# +-------------+-----+--------+----------------+-------------+-----------------+----------------+-----------+-------+--------+---------------+---------------------+----------------+------------------+--------------------+----------------+------------------------+
# | customer_id | age | gender | item_purchased |   category  | purchase_amount |    location    |    size   | color | season | review_rating | subscription_status | shipping_type  | discount_applied | previous_purchases | payment_method | frequency_of_purchases |
# +-------------+-----+--------+----------------+-------------+-----------------+----------------+-----------+-------+--------+---------------+---------------------+----------------+------------------+--------------------+----------------+------------------------+
# |     2701    |  22 | Female |    T-shirt     |   Clothing  |       68.0      |   California   |     XL    | Olive | Winter |      3.2      |          No         |    Standard    |        No        |        36.0        |      Cash      |         Weekly         |
# |     521     |  51 |  Male  |   Sunglasses   | Accessories |       84.0      | South Carolina | Free Size | White | Spring |      3.9      |         Yes         | Free Shipping  |       Yes        |        20.0        |   Debit Card   |       Quarterly        |
# |     3157    |  18 | Female |     Shirt      |   Clothing  |       50.0      |    Montana     |     M     | Black | Winter |      3.1      |          No         | 2-Day Shipping |        No        |        18.0        |      Cash      |        Monthly         |
# +-------------+-----+--------+----------------+-------------+-----------------+----------------+-----------+-------+--------+---------------+---------------------+----------------+------------------+--------------------+----------------+------------------------+

# %%
# %%sql
# SELECT
#     shipping_type,
#     ROUND(SUM(purchase_amount),2) AS revenue,
#     round(AVG(purchase_amount),2) as Avg_purchase
# FROM
#     customer
# GROUP BY
#     shipping_type
# ORDER BY
#     Avg_purchase DESC;
#
# -- Business Problem - Unclear if faster shipping leads to higher spending.
#
#
# -- Impact
# 			--Helps optimize shipping pricing strategy
# 			--Encourages premium shipping adoption
# 			--Increases average order value
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 6 rows affected.
# +----------------+-----------+--------------+
# | shipping_type  |  revenue  | Avg_purchase |
# +----------------+-----------+--------------+
# |    Express     | 413734.34 |    345.07    |
# |    Standard    | 396298.05 |    329.97    |
# | 2-Day Shipping |  38080.0  |    60.73     |
# | Free Shipping  |  40777.0  |    60.41     |
# |  Store Pickup  |  38931.0  |    59.89     |
# |  Next Day Air  |  37993.0  |    58.63     |
# +----------------+-----------+--------------+

# %%
# %%sql
# --Do subscribed customers spend more ? Compare average speed and total revenue between subscribers and non-subscribers.
# SELECT
#     subscription_status,
#     ROUND(SUM(purchase_amount),2) AS total_revenue,
#     round(AVG(purchase_amount),2) as Avg_purchase
# FROM
#     customer
# GROUP BY
#     subscription_status
# ORDER BY
#     total_revenue DESC;
#
# -- Business Problem - The effectiveness of subscription programs is unknown.
#
# -- Impact
# 			--Validates subscription model performance
# 			--Improves customer loyalty programs
# 			--Increases customer lifetime value (CLV)
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 2 rows affected.
# +---------------------+---------------+--------------+
# | subscription_status | total_revenue | Avg_purchase |
# +---------------------+---------------+--------------+
# |          No         |   552364.21   |    161.46    |
# |         Yes         |   413449.18   |    261.84    |
# +---------------------+---------------+--------------+

# %%
# %%sql
#     -- Top 5 products with highest discount usage %
# SELECT
# 	item_purchased,
# 	COUNT(item_purchased) AS total_number_of_times_sold,
# 	COUNT(CASE WHEN discount_applied='Yes' THEN 1 END) AS  Number_of_times_sold_when_disocunt_applied,
# 	COUNT(CASE WHEN discount_applied='Yes' THEN 1 END) *100.0 / COUNT(*) AS discount_percent
# FROM customer
# GROUP BY item_purchased
# ORDER BY discount_percent DESC
#
# --  Business Problem - Some products may be overly dependent on discounts.
#
# -- Impact:-
# 			--Identifies discount-driven products
# 			--Helps optimize pricing strategy
# 			--Reduces profit margin loss
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 30 rows affected.
# +----------------+----------------------------+--------------------------------------------+------------------+
# | item_purchased | total_number_of_times_sold | Number_of_times_sold_when_disocunt_applied | discount_percent |
# +----------------+----------------------------+--------------------------------------------+------------------+
# |     Laptop     |            143             |                     74                     |     51.74825     |
# |     Phone      |            171             |                     88                     |     51.46199     |
# |   Headphones   |            166             |                     85                     |     51.20482     |
# |      Hat       |            154             |                     77                     |     50.00000     |
# |     Watch      |            157             |                     78                     |     49.68153     |
# |    Sneakers    |            145             |                     72                     |     49.65517     |
# |     Shirt      |            315             |                    156                     |     49.52381     |
# |      Coat      |            161             |                     79                     |     49.06832     |
# |    Sweater     |            164             |                     79                     |     48.17073     |
# |     Pants      |            171             |                     81                     |     47.36842     |
# +----------------+----------------------------+--------------------------------------------+------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Segment customer into new, returning and loyal based on their total number of previous purchase,
# -- and show the count of each segment.
# SELECT
#     CASE
#         WHEN previous_purchases = '0' THEN 'New_customer'
#         WHEN previous_purchases BETWEEN 1 AND 10 THEN 'returning_customer'
#     ELSE 'Loyal_customer'
# END AS customer_segment,
#     COUNT(*) AS customer_count
# FROM customer
# GROUP BY
#     CASE
#         WHEN previous_purchases = '0' THEN 'New_customer'
#         WHEN previous_purchases BETWEEN 1 AND 10 THEN 'returning_customer'
#     ELSE 'Loyal_customer'
# END;
#
# -- Business Problem - Lack of customer segmentation leads to generic strategies.
#
#
# -- Impact -
# 			--Enables personalized marketing
# 			--Improves retention strategies
# 			--Increases conversion rates
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 3 rows affected.
# +--------------------+----------------+
# |  customer_segment  | customer_count |
# +--------------------+----------------+
# |   Loyal_customer   |      3537      |
# | returning_customer |      902       |
# |    New_customer    |      561       |
# +--------------------+----------------+

# %%
# %%sql
# -- What are the top 3 most purchased products within each category ?
# WITH CTE AS
# (
# SELECT
# 	category,
# 	item_purchased,
# 	COUNT(item_purchased) AS most_purchased,
# 	RANK() OVER (PARTITION BY category ORDER BY COUNT(item_purchased) DESC) AS RNK
# FROM customer
# GROUP BY category,item_purchased
# )
# SELECT * FROM CTE
# WHERE RNK <=3
#
# -- Business Problem - The company doesn’t know top-performing products within categories.
#
#
# -- Impact
# 			--Improves product placement & recommendations
# 			--Helps inventory optimization
# 			--Increases sales through best-sellers
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 15 rows affected.
# +-------------+----------------+----------------+-----+
# |   category  | item_purchased | most_purchased | RNK |
# +-------------+----------------+----------------+-----+
# | Accessories |    Jewelry     |      171       |  1  |
# | Accessories |      Bag       |      164       |  2  |
# | Accessories |   Sunglasses   |      161       |  3  |
# | Accessories |      Belt      |      161       |  3  |
# |   Clothing  |     Shirt      |      315       |  1  |
# |   Clothing  |     Pants      |      171       |  2  |
# |   Clothing  |     Blouse     |      171       |  2  |
# | Electronics |     Phone      |      171       |  1  |
# | Electronics |   Headphones   |      166       |  2  |
# | Electronics |     Watch      |      157       |  3  |
# +-------------+----------------+----------------+-----+
# Truncated to displaylimit of 10.

# %%
# %%sql
# -- Are customers who are repeat buyers (more than 5 previous purchases) also likely to subscribe ?
# SELECT
# 	CASE
# 		WHEN previous_purchases > 5 THEN 'Repeat Buyers'
# 		ELSE 'Normal Buyers'
# 	END AS customer_type,
# 	subscription_status,
# 	COUNT(*) AS customer_count,
# 	COUNT(*) * 100.0 / SUM(COUNT(*)) OVER (PARTITION BY CASE
# 										WHEN previous_purchases > 5 THEN 'Repeat Buyers'
# 										ELSE 'Normal Buyers'
# 									END
# 									) AS percents
#
# FROM customer
# GROUP BY CASE
# 		WHEN previous_purchases > 5 THEN 'Repeat Buyers'
# 		ELSE 'Normal Buyers'
# 	END,subscription_status
#
# -- Business Problem - Unclear relationship between loyalty and subscription.
#
# -- Impact -
# 			--Improves subscription targeting
# 			--Increases conversion to paid programs
# 			--increase customer retention strategy
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 4 rows affected.
# +---------------+---------------------+----------------+----------+
# | customer_type | subscription_status | customer_count | percents |
# +---------------+---------------------+----------------+----------+
# | Normal Buyers |          No         |      658       | 62.84623 |
# | Normal Buyers |         Yes         |      389       | 37.15377 |
# | Repeat Buyers |          No         |      2763      | 69.89628 |
# | Repeat Buyers |         Yes         |      1190      | 30.10372 |
# +---------------+---------------------+----------------+----------+

# %%
# %%sql
# -- What is the revenue contribution of each age group
# SELECT
# 	CASE
# 		WHEN age BETWEEN 18 AND 25 THEN '18-25'
# 		WHEN Age BETWEEN 26 AND 35 THEN '26-35'
# 		WHEN Age BETWEEN 36 AND 50 THEN '35-50'
# 		ELSE '51+'
# 	END AS age_group,
# 	ROUND(SUM(purchase_amount),2) AS total_revenue
# FROM customer
# GROUP BY CASE
# 		WHEN age BETWEEN 18 AND 25 THEN '18-25'
# 		WHEN Age BETWEEN 26 AND 35 THEN '26-35'
# 		WHEN Age BETWEEN 36 AND 50 THEN '35-50'
# 		ELSE '51+'
# 	END
# 	ORDER BY total_revenue DESC
#
# -- Business Problem:- No visibility into which age group contributes most to revenue.
#
# -- Impact -
# 			--Enables age-based targeting
# 			--Enhances marketing efficiency
# Out:
# Running query in 'mysql+pymysql://root:***@localhost:3306/customer_behaviour'
# 4 rows affected.
# +-----------+---------------+
# | age_group | total_revenue |
# +-----------+---------------+
# |    51+    |   387655.87   |
# |   35-50   |   258521.89   |
# |   26-35   |   173003.17   |
# |   18-25   |   146632.46   |
# +-----------+---------------+
